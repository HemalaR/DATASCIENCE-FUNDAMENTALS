# %%
import pandas as pd
import matplotlib.pyplot as plt
Data=pd.read_csv('C:/Users/student/Desktop/PRAKASH B/Vanilla_bp.csv')
#creating plot
plt.boxplot(Data, vert = None)
#show plot
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
Data = pd.read_csv('C:/Users/student/Desktop/PRAKASH B/tips_bp.csv')
Data.boxplot(column=['total_bill'])
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
Data = pd.read_csv('C:/Users/student/Desktop/PRAKASH B/tips_bp.csv')
Data.boxplot(by='day',column=['total_bill'],grid=False)
plt.ylabel('Total Bill')
plt.xlabel('Days')
plt.show()
